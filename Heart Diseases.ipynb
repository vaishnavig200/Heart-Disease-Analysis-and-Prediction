# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Reading CSV file

# %%
df=pd.read_csv('heart.csv')
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df.shape
# Out:
# (303, 14)

# %% [markdown]
# This shows that the CSV has 303 rows and 14 columns

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %% [markdown]
# We can see the specific column names here

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# isnull command displays how many null values are there in your data set. It shows there are no null values.

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
# age         303 non-null int64
# sex         303 non-null int64
# cp          303 non-null int64
# trestbps    303 non-null int64
# chol        303 non-null int64
# fbs         303 non-null int64
# restecg     303 non-null int64
# thalach     303 non-null int64
# exang       303 non-null int64
# oldpeak     303 non-null float64
# slope       303 non-null int64
# ca          303 non-null int64
# thal        303 non-null int64
# target      303 non-null int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB
# None

# %% [markdown]
# This provides the datatype and non-null count of the data set.

# %% [markdown]
# Finding the Co-relation among the attributes:

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True,cmap="terrain", fmt='.1f')
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),annot=True,cmap="terrain")

# %%
sns.pairplot(data=df)

# %%
df.hist(figsize=(12,12),layout=(5,3));

# %%
df.plot(kind='box',subplots=True, layout=(5,3), figsize=(12,12))
plt.show()

# %%
sns.catplot(data=df, x='sex', y='age', hue='target', palette='spring')

# %%
sns.barplot(data=df, x='sex', y='age', hue='target', palette='husl')

# %%
df['sex'].value_counts()
# Out:
# 1    207
# 0     96
# Name: sex, dtype: int64

# %% [markdown]
# This means 207-Men and 96-Women are present.

# %%
df['target'].value_counts()
# Out:
# 1    165
# 0    138
# Name: target, dtype: int64

# %%
df['thal'].value_counts()
# Out:
# 2    166
# 3    117
# 1     18
# 0      2
# Name: thal, dtype: int64

# %%
sns.countplot(data=df, x='sex', hue='target', palette='spring')

# %% [markdown]
# 0 -> not having Heart Disease , 1 -> Having Heart Disease

# %%
sns.countplot(data=df, x='target')

# %%
sns.countplot(data=df, x='ca', hue='target',palette='BuPu')

# %%
sns.countplot(data=df, x='thal', hue='target',palette='spring')

# %% [markdown]
# thal  3=normal , 6=fixed defect, 7=reversable defect

# %%
sns.countplot(data=df, x='thal', hue='sex',palette='BuPu')

# %%
df['cp'].value_counts()
# Out:
# 0    143
# 2     87
# 1     50
# 3     23
# Name: cp, dtype: int64

# %%
sns.countplot(data=df, x='cp', hue='target',palette='spring')

# %%
sns.countplot(data=df, x='cp', hue='sex',palette='rocket')

# %% [markdown]
# chestpain encountered by males and females

# %%
sns.boxplot(data=df, x='sex', y='chol',hue='target',palette='rocket')

# %%
sns.barplot(data=df, x='sex', y='cp',hue='target',palette='rocket')

# %%
sns.barplot(data=df, x='sex', y='thal',hue='target',palette='cividis')

# %%
sns.barplot(data=df, x='sex', y='oldpeak',hue='target',palette='nipy_spectral')

# %% [markdown]
# FBS(Fasting Blood Sugar> 120mg/dl)(1=true;0=false) and chest pain relation

# %%
df['fbs'].value_counts()
# Out:
# 0    258
# 1     45
# Name: fbs, dtype: int64

# %%
sns.barplot(data=df, x='fbs', y='chol',hue='target',palette='nipy_spectral')

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
StandardScaler = StandardScaler()  
columns_to_scale = ['age','trestbps','chol','thalach','oldpeak']
df[columns_to_scale] = StandardScaler.fit_transform(df[columns_to_scale])

# %%
df.head()
# Out:
#         age  sex  cp  trestbps      chol  fbs  restecg   thalach  exang  \
# 0  0.952197    1   3  0.763956 -0.256334    1        0  0.015443      0
# 1 -1.915313    1   2 -0.092738  0.072199    0        1  1.633471      0
# 2 -1.474158    0   1 -0.092738 -0.816773    0        0  0.977514      0
# 3  0.180175    1   1 -0.663867 -0.198357    0        1  1.239897      0
# 4  0.290464    0   0 -0.663867  2.082050    0        1  0.583939      1
#
#     oldpeak  slope  ca  thal  target
# 0  1.087338      0   0     1       1
# 1  2.122573      0   0     2       1
# 2  0.310912      2   0     2       1
# 3 -0.206705      2   0     2       1
# 4 -0.379244      2   0     2       1

# %%
X= df.drop(['target'], axis=1)
y= df['target']

# %%
X_train, X_test,y_train, y_test=train_test_split(X,y,test_size=0.3,random_state=40)

# %%
print('X_train-', X_train.size)
print('X_test-',X_test.size)
print('y_train-', y_train.size)
print('y_test-', y_test.size)
# Out:
# X_train- 2756
# X_test- 1183
# y_train- 212
# y_test- 91

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()

model1=lr.fit(X_train,y_train)
prediction1=model1.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

cm=confusion_matrix(y_test,prediction1)
cm
# Out:
# array([[36,  4],
#        [ 3, 48]])

# %%
sns.heatmap(cm, annot=True,cmap='BuPu')

# %%
TP=cm[0][0]
TN=cm[1][1]
FN=cm[1][0]
FP=cm[0][1]
print('Testing Accuracy:',(TP+TN)/(TP+TN+FN+FP))
#total correct prediction / total prediction
# Out:
# Testing Accuracy: 0.9230769230769231

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,prediction1)
# Out:
# 0.9230769230769231

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, prediction1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.90      0.91        40
#            1       0.92      0.94      0.93        51
#
#     accuracy                           0.92        91
#    macro avg       0.92      0.92      0.92        91
# weighted avg       0.92      0.92      0.92        91

# %%
from sklearn.tree import DecisionTreeClassifier

dtc=DecisionTreeClassifier()
model2=dtc.fit(X_train,y_train)
prediction2=model2.predict(X_test)
cm2= confusion_matrix(y_test,prediction2)

# %%
cm2
# Out:
# array([[31,  9],
#        [12, 39]])

# %%
accuracy_score(y_test,prediction2)
# Out:
# 0.7692307692307693

# %%
print(classification_report(y_test, prediction2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.78      0.75        40
#            1       0.81      0.76      0.79        51
#
#     accuracy                           0.77        91
#    macro avg       0.77      0.77      0.77        91
# weighted avg       0.77      0.77      0.77        91

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

rfc=RandomForestClassifier()
model3 = rfc.fit(X_train, y_train)
prediction3 = model3.predict(X_test)
confusion_matrix(y_test, prediction3)
# Out:
# array([[33,  7],
#        [ 6, 45]])

# %%
accuracy_score(y_test, prediction3)
# Out:
# 0.8571428571428571

# %%
print(classification_report(y_test, prediction3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.82      0.84        40
#            1       0.87      0.88      0.87        51
#
#     accuracy                           0.86        91
#    macro avg       0.86      0.85      0.85        91
# weighted avg       0.86      0.86      0.86        91

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %%
from sklearn.svm import SVC

svm=SVC()
model4=svm.fit(X_train,y_train)
prediction4=model4.predict(X_test)
cm4= confusion_matrix(y_test,prediction4)

# %%
cm4
# Out:
# array([[33,  7],
#        [ 2, 49]])

# %%
accuracy_score(y_test, prediction4)
# Out:
# 0.9010989010989011

# %%
from sklearn.naive_bayes import GaussianNB

NB = GaussianNB()
model5 = NB.fit(X_train, y_train)
prediction5 = model5.predict(X_test)
cm5= confusion_matrix(y_test, prediction5)

# %%
cm5
# Out:
# array([[35,  5],
#        [ 6, 45]])

# %%
accuracy_score(y_test, prediction5)
# Out:
# 0.8791208791208791

# %%
print('cm4', cm4)
print('-----------')
print('cm5',cm5)
# Out:
# cm4 [[33  7]
#  [ 2 49]]
# -----------
# cm5 [[35  5]
#  [ 6 45]]

# %%
from sklearn.neighbors import KNeighborsClassifier

KNN = KNeighborsClassifier()
model6 = KNN.fit(X_train, y_train)
prediction6 = model6.predict(X_test)
cm6= confusion_matrix(y_test, prediction5)
cm6
# Out:
# array([[35,  5],
#        [ 6, 45]])

# %%
print('KNN :', accuracy_score(y_test, prediction6))
print('lr :', accuracy_score(y_test, prediction1))
print('dtc :', accuracy_score(y_test, prediction2))
print('rfc :', accuracy_score(y_test, prediction3))
print('NB: ', accuracy_score(y_test, prediction4))
print('SVC :', accuracy_score(y_test, prediction5))
# Out:
# KNN : 0.8351648351648352
# lr : 0.9230769230769231
# dtc : 0.7692307692307693
# rfc : 0.8571428571428571
# NB:  0.9010989010989011
# SVC : 0.8791208791208791

# %% [markdown]
# Best accuracy is given by Logistic regression followed by NB and SVC

# %%
countNoDisease = len(df[df.target == 0])
countHaveDisease = len(df[df.target == 1])
print("Percentage of Patients Haven't Heart Disease: {:.2f}%".format((countNoDisease / (len(df.target))*100)))
print("Percentage of Patients Have Heart Disease: {:.2f}%".format((countHaveDisease / (len(df.target))*100)))
# Out:
# Percentage of Patients Haven't Heart Disease: 45.54%
# Percentage of Patients Have Heart Disease: 54.46%
